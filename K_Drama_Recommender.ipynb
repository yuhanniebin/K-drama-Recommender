# %%
# !pip install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.1.3)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.0.3)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.2.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)
# Installing collected packages: jedi, pyvis
# Successfully installed jedi-0.19.1 pyvis-0.3.2

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MultiLabelBinarizer
import networkx as nx
from pyvis.network import Network
import IPython
from IPython.core.display import display, HTML

# %% [markdown]
# #1. Import Dataset

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Load dataset from Google Drive
path = "/content/drive/My Drive/UCLA_Data_Science_Clubs/Korean Drama (DataRes)/kdrama.csv"
kdrama_df = pd.read_csv(path)

# %%
# Check first few rows of dataset
kdrama_df.head(5)
# Out:
#                   Name                   Aired Date  Year of release  \
# 0       Move to Heaven                 May 14, 2021             2021
# 1       Flower of Evil  Jul 29, 2020 - Sep 23, 2020             2020
# 2    Hospital Playlist  Mar 12, 2020 - May 28, 2020             2020
# 3  Hospital Playlist 2  Jun 17, 2021 - Sep 16, 2021             2021
# 4            My Mister  Mar 21, 2018 - May 17, 2018             2018
#
#   Original Network              Aired On  Number of Episodes       Duration  \
# 0          Netflix                Friday                  10        52 min.
# 1              tvN   Wednesday, Thursday                  16  1 hr. 10 min.
# 2   Netflix,  tvN               Thursday                  12  1 hr. 30 min.
# 3   Netflix,  tvN               Thursday                  12  1 hr. 40 min.
# 4              tvN   Wednesday, Thursday                  16  1 hr. 17 min.
#
#                           Content Rating  Rating  \
# 0  18+ Restricted (violence & profanity)     9.2
# 1                15+ - Teens 15 or older     9.1
# 2                15+ - Teens 15 or older     9.1
# 3                15+ - Teens 15 or older     9.1
# 4                15+ - Teens 15 or older     9.1
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  Although Baek Hee Sung is hiding a dark secret...
# 2  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                      Genre  \
# 0                   Life,  Drama,  Family
# 1  Thriller,  Romance,  Crime,  Melodrama
# 2   Friendship,  Romance,  Life,  Medical
# 3   Friendship,  Romance,  Life,  Medical
# 4   Psychological,  Life,  Drama,  Family
#
#                                                 Tags  \
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...
# 1  Married Couple, Deception, Suspense, Family Se...
# 2  Strong Friendship, Multiple Mains, Best Friend...
# 3  Workplace, Strong Friendship, Best Friends, Mu...
# 4  Age Gap, Nice Male Lead, Strong Female Lead, H...
#
#                      Director    Screenwriter  \
# 0                 Kim Sung Ho    Yoon Ji Ryun
# 1  Kim Chul Gyu, Yoon Jong Ho    Yoo Jung Hee
# 2                 Shin Won Ho    Lee Woo Jung
# 3                 Shin Won Ho    Lee Woo Jung
# 4   Kim Won Suk, Kim Sang Woo  Park Hae Young
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 2  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
#
#                    Production companies Rank
# 0  Page One Film, Number Three Pictures   #1
# 1                         Monster Union   #2
# 2                 Egg Is Coming, CJ ENM   #3
# 3                 Egg Is Coming, CJ ENM   #4
# 4                      Chorokbaem Media   #5

# %% [markdown]
# #2. Data Cleaning

# %%
# Check data type of columns
kdrama_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  250 non-null    object
#  1   Aired Date            250 non-null    object
#  2   Year of release       250 non-null    int64
#  3   Original Network      250 non-null    object
#  4   Aired On              250 non-null    object
#  5   Number of Episodes    250 non-null    int64
#  6   Duration              250 non-null    object
#  7   Content Rating        245 non-null    object
#  8   Rating                250 non-null    float64
#  9   Synopsis              250 non-null    object
#  10  Genre                 250 non-null    object
#  11  Tags                  250 non-null    object
#  12  Director              249 non-null    object
#  13  Screenwriter          249 non-null    object
#  14  Cast                  250 non-null    object
#  15  Production companies  248 non-null    object
#  16  Rank                  250 non-null    object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 33.3+ KB

# %%
# Statistical summary
kdrama_df.describe()
# Out:
#        Year of release  Number of Episodes      Rating
# count        250.00000          250.000000  250.000000
# mean        2018.25600           19.064000    8.534000
# std            3.26452           13.245743    0.221359
# min         2003.00000            1.000000    8.300000
# 25%         2017.00000           16.000000    8.300000
# 50%         2019.00000           16.000000    8.500000
# 75%         2021.00000           20.000000    8.700000
# max         2022.00000          133.000000    9.200000

# %%
# Dimensions of dataset
kdrama_df.shape
# Out:
# (250, 17)

# %% [markdown]
# Dataset consists of top 250 dramas with 17 features.

# %% [markdown]
# ### **Anomalies**

# %%
# Check anomalies (Year of Release)
kdrama_df[kdrama_df["Year of release"] < 2010]
# Out:
#                     Name                   Aired Date  Year of release  \
# 72   Jewel in the Palace  Sep 15, 2003 - Mar 23, 2004             2003
# 117       Queen Seon Duk  May 25, 2009 - Dec 22, 2009             2009
# 202               Jumong   May 15, 2006 - Mar 6, 2007             2006
# 240        Coffee Prince   Jul 2, 2007 - Aug 28, 2007             2007
#
#     Original Network          Aired On  Number of Episodes       Duration  \
# 72               MBC   Monday, Tuesday                  54   1 hr. 5 min.
# 117              MBC   Monday, Tuesday                  62   1 hr. 5 min.
# 202              MBC   Monday, Tuesday                  81  1 hr. 10 min.
# 240              MBC   Monday, Tuesday                  17        60 min.
#
#               Content Rating  Rating  \
# 72   13+ - Teens 13 or older     8.6
# 117  15+ - Teens 15 or older     8.5
# 202  15+ - Teens 15 or older     8.3
# 240  15+ - Teens 15 or older     8.3
#
#                                               Synopsis  \
# 72   About 500 years ago during the time of Chosun ...
# 117  The story of a beautiful queen, who has to giv...
# 202  Jumong was the founder of Goguryeo in 37 BC. H...
# 240  Choi Han Gyul is the grandson of chairwoman Ba...
#
#                                       Genre  \
# 72   Food,  Historical,  Romance,  Medical
# 117   Historical, Romance, Drama, Political
# 202   Adventure, Historical, Romance, Drama
# 240            Food, Comedy, Romance, Drama
#
#                                                   Tags  \
# 72   Cooking, Strong Female Lead, Royal Rules And E...
# 117  Power Struggle, Royalty, Smart Female Lead, Fe...
# 202  Leadership, Strong Female Lead, Power Struggle...
# 240  Cross-Dressing, Hidden Identity, Boss-Employee...
#
#                           Director                    Screenwriter  \
# 72                  Lee Byung Hoon                  Kim Young Hyun
# 117  Park Hong Kyun, Kim Keun Hong  Kim Young Hyun, Park Sang Yeon
# 202    Lee Joo Hwan, Kim Keun Hong    Choi Wan Kyu, Jung Hyung Soo
# 240                  Lee Yoon Jung      Jang Hyun Joo, Lee Jung Ah
#
#                                                   Cast  \
# 72   Lee Young Ae, Ji Jin Hee, Hong Ri Na, Im Ho, Y...
# 117  Lee Yo Won, Go Hyun Jung, Park Ye Jin, Yoo Seu...
# 202  Song Il Gook, Han Hye Jin, Kim Seung Soo, Jeon...
# 240  Gong Yoo, Yoon Eun Hye, Lee Sun Kyun, Chae Jun...
#
#          Production companies  Rank
# 72                        MBC   #73
# 117       Time Box Production  #118
# 202  Chorokbaem Media, Olive9  #203
# 240                       NaN  #241

# %%
# Check anomalies (Number of Episodes)
kdrama_df[kdrama_df["Number of Episodes"] > 50]
# Out:
#                      Name                   Aired Date  Year of release  \
# 72    Jewel in the Palace  Sep 15, 2003 - Mar 23, 2004             2003
# 83             Empress Ki  Oct 28, 2013 - Apr 29, 2014             2013
# 84   My Father is Strange  Mar  4, 2017 - Aug 27, 2017             2017
# 85             Once Again  Mar 28, 2020 - Sep 13, 2020             2020
# 117        Queen Seon Duk  May 25, 2009 - Dec 22, 2009             2009
# 131               Dong Yi  Mar 22, 2010 - Oct 12, 2010             2010
# 202                Jumong   May 15, 2006 - Mar 6, 2007             2006
# 204            Ugly Alert  May 20, 2013 - Nov 29, 2013             2013
# 226           Five Enough  Feb 20, 2016 - Aug 21, 2016             2016
#
#     Original Network                                      Aired On  \
# 72               MBC                               Monday, Tuesday
# 83               MBC                               Monday, Tuesday
# 84              KBS2                              Saturday, Sunday
# 85              KBS2                              Saturday, Sunday
# 117              MBC                               Monday, Tuesday
# 131              MBC                               Monday, Tuesday
# 202              MBC                               Monday, Tuesday
# 204              SBS  Monday, Tuesday, Wednesday, Thursday, Friday
# 226             KBS2                              Saturday, Sunday
#
#      Number of Episodes       Duration           Content Rating  Rating  \
# 72                   54   1 hr. 5 min.  13+ - Teens 13 or older     8.6
# 83                   51   1 hr. 5 min.  15+ - Teens 15 or older     8.6
# 84                   52   1 hr. 6 min.  15+ - Teens 15 or older     8.6
# 85                  100        35 min.  15+ - Teens 15 or older     8.6
# 117                  62   1 hr. 5 min.  15+ - Teens 15 or older     8.5
# 131                  60   1 hr. 5 min.  15+ - Teens 15 or older     8.5
# 202                  81  1 hr. 10 min.  15+ - Teens 15 or older     8.3
# 204                 133        35 min.  15+ - Teens 15 or older     8.3
# 226                  54  1 hr. 10 min.  15+ - Teens 15 or older     8.3
#
#                                               Synopsis  \
# 72   About 500 years ago during the time of Chosun ...
# 83   Genghis Khan built an empire that spanned vast...
# 84   This drama is about a family that lives on the...
# 85   "Once Again" is the story of the eventful Song...
# 117  The story of a beautiful queen, who has to giv...
# 131  "Dong Yi" is a historical drama based on the l...
# 202  Jumong was the founder of Goguryeo in 37 BC. H...
# 204  The story of a man named Gong Joon Soo who sac...
# 226  After losing his wife five years ago, Lee Sang...
#
#                                              Genre  \
# 72          Food,  Historical,  Romance,  Medical
# 83   Historical,  Romance,  Melodrama,  Political
# 84              Comedy,  Romance,  Drama,  Family
# 85              Comedy,  Romance,  Drama,  Family
# 117          Historical, Romance, Drama, Political
# 131        Adventure, Historical, Mystery, Romance
# 202          Adventure, Historical, Romance, Drama
# 204                   Business, Romance, Melodrama
# 226              Comedy, Romance, Drama, Melodrama
#
#                                                   Tags  \
# 72   Cooking, Strong Female Lead, Royal Rules And E...
# 83   Smart Female Lead, Strong Female Lead, Power S...
# 84   Family Secret, Sisterhood, Eccentric Female Le...
# 85   Divorce, Family Relationship, Multiple Couples...
# 117  Power Struggle, Royalty, Smart Female Lead, Fe...
# 131  Harem, Joseon Dynasty, Investigation, King Mal...
# 202  Leadership, Strong Female Lead, Power Struggle...
# 204  Rich Woman/Poor Man, Nice Male Lead, Strong Fe...
# 226  Motherhood, Strong Female Lead, Multiple Coupl...
#
#                           Director                      Screenwriter  \
# 72                  Lee Byung Hoon                    Kim Young Hyun
# 83          Han Hee, Lee Sung Joon  Jang Young Chul, Jung Kyung Soon
# 84                    Lee Jae Sang                      Lee Jung Sun
# 85                    Lee Jae Sang                    Yang Hee Seung
# 117  Park Hong Kyun, Kim Keun Hong    Kim Young Hyun, Park Sang Yeon
# 131  Kim Sang Hyub, Lee Byung Hoon                      Kim Yi Young
# 202    Lee Joo Hwan, Kim Keun Hong      Choi Wan Kyu, Jung Hyung Soo
# 204   Shin Yoon Sub, Min Yeon Hong                       Jung Ji Woo
# 226                   Kim Jung Gyu                    Jung Hyun Jung
#
#                                                   Cast  \
# 72   Lee Young Ae, Ji Jin Hee, Hong Ri Na, Im Ho, Y...
# 83   Ha Ji Won, Ji Chang Wook, Joo Jin Mo, Baek Jin...
# 84   Kim Yeong Cheol, Kim Hae Sook, Ryu Soo Young, ...
# 85   Chun Ho Jin, Cha Hwa Yun, Lee Jung Eun, Oh Dae...
# 117  Lee Yo Won, Go Hyun Jung, Park Ye Jin, Yoo Seu...
# 131  Han Hyo Joo, Ji Jin Hee, Lee So Yeon, Bae Soo ...
# 202  Song Il Gook, Han Hye Jin, Kim Seung Soo, Jeon...
# 204  Im Joo Hwan, Kang So Ra, Kang  Byul, Choi  Tae...
# 226  Ahn Jae Wook, So Yoo Jin, Sung Hoon, Shin Hye ...
#
#                      Production companies  Rank
# 72                                    MBC   #73
# 83                       Victory Contents   #84
# 84                                    iHQ   #85
# 85   Bon Factory Worldwide, Studio Dragon   #86
# 117                   Time Box Production  #118
# 131        Lydus Contents Company, AStory  #132
# 202              Chorokbaem Media, Olive9  #203
# 204     Shinyoung E&C Group, Human Nature  #205
# 226                                AStory  #227

# %% [markdown]
# **Note:** After doing some fact-checking, it seems like these dramas really have that many episodes. For those of you guys analyzing "Year of Release" or "Number of Episodes", please take note of these anomalies before deciding on whether to include or exclude them.

# %% [markdown]
# ###**Missing Values**

# %%
# Check number of missing values
kdrama_df.isnull().sum()
# Out:
# Name                    0
# Aired Date              0
# Year of release         0
# Original Network        0
# Aired On                0
# Number of Episodes      0
# Duration                0
# Content Rating          5
# Rating                  0
# Synopsis                0
# Genre                   0
# Tags                    0
# Director                1
# Screenwriter            1
# Cast                    0
# Production companies    2
# Rank                    0
# dtype: int64

# %%
# Missing value in Content Rating
kdrama_df[kdrama_df["Content Rating"].isnull()]
# Out:
#                      Name                   Aired Date  Year of release  \
# 140     One Dollar Lawyer  Sep 23, 2022 - Nov 11, 2022             2022
# 146                  Duel   Jun 3, 2017 - Jul 23, 2017             2017
# 171                Player  Sep 29, 2018 - Nov 11, 2018             2018
# 190  The Mysterious Class  Nov 12, 2021 - Dec 31, 2021             2021
# 230             Liar Game  Oct 20, 2014 - Nov 25, 2014             2014
#
#     Original Network          Aired On  Number of Episodes       Duration  \
# 140              SBS  Friday, Saturday                  12  1 hr. 10 min.
# 146              OCN  Saturday, Sunday                  16   1 hr. 3 min.
# 171              OCN  Saturday, Sunday                  14   1 hr. 5 min.
# 190          YouTube            Friday                   8        20 min.
# 230              tvN   Monday, Tuesday                  12   1 hr. 3 min.
#
#     Content Rating  Rating                                           Synopsis  \
# 140            NaN     8.4  Cheon Ji Hun is a lawyer with unusual flair. H...
# 146            NaN     8.4  Jang Deuk Cheon, a hardened detective cop whos...
# 171            NaN     8.4  A police redemption team consisting of a swind...
# 190            NaN     8.3  "There are 21 students in our class." "What ar...
# 230            NaN     8.3  Various contestants take part in a game show w...
#
#                                        Genre  \
# 140                       Comedy, Law, Drama
# 146                Thriller, Mystery, Sci-Fi
# 171        Action, Thriller, Mystery, Comedy
# 190     Mystery, Horror, Youth, Supernatural
# 230  Thriller, Mystery, Psychological, Drama
#
#                                                   Tags       Director  \
# 140  Lawyer Male Lead, Former Prosecutor Male Lead,...   Kim Jae Hyun
# 146  Amnesia, Human Experimentation, Kidnapping, Tr...   Lee Jong Jae
# 171  Strong Female Lead, Corruption, Hidden Identit...    Go Jae Hyun
# 190  Student, Ghost, Investigation, High School, Sc...      Ha Han Me
# 230  Naive Female Lead, Debt, Game Show, Swindler M...  Kim Hong Seon
#
#                       Screenwriter  \
# 140  Choi Soo Jin, Choi Chang Hwan
# 146                   Kim Yoon Joo
# 171                 Shin Jae Hyung
# 190                    Han Song-yi
# 230                   Ryu Yong Jae
#
#                                                   Cast  \
# 140  Namkoong Min, Kim Ji Eun, Choi Dae Hoon, Lee D...
# 146  Jung Jae Young, Kim Jung Eun, Yang Se Jong, Se...
# 171  Song Seung Heon, Krystal Jung, Lee Si Eon, Tae...
# 190  Choi Hyun Suk, Park Ji Hoon, Yoshi, Kim Jun Ky...
# 230  Lee Sang Yoon, Kim So Eun, Shin Sung Rok, Cha ...
#
#           Production companies  Rank
# 140                   Studio S  #141
# 146           Chorokbaem Media  #147
# 171                iWill Media  #172
# 190           YG Entertainment  #191
# 230  Apollo Pictures, Fantagio  #231

# %%
# Replace missing values in Content Rating
kdrama_df.loc[140, "Content Rating"] = "13+ - Teens 13 or older"
kdrama_df.loc[146, "Content Rating"] = "Unrated"
kdrama_df.loc[171, "Content Rating"] = "15+ - Teens 15 or older"
kdrama_df.loc[190, "Content Rating"] = "G - All Ages"
kdrama_df.loc[230, "Content Rating"] = "Unrated"

# %%
# Frequency count in Content Rating
kdrama_df["Content Rating"].value_counts()
# Out:
# 15+ - Teens 15 or older                  217
# 18+ Restricted (violence & profanity)     20
# 13+ - Teens 13 or older                    9
# Unrated                                    2
# G - All Ages                               2
# Name: Content Rating, dtype: int64

# %%
# Missing value in Director
kdrama_df[kdrama_df["Director"].isnull()]
# Out:
#                              Name   Aired Date  Year of release  \
# 192  It's Okay, That's Friendship  Mar 5, 2021             2021
#
#     Original Network Aired On  Number of Episodes Duration Content Rating  \
# 192          YouTube   Friday                   1  20 min.   G - All Ages
#
#      Rating                                           Synopsis         Genre  \
# 192     8.3  The 12 members of TREASURE take on acting for ...  Comedy, Life
#
#                                                   Tags Director Screenwriter  \
# 192  Idol Male Lead, Multiple Mains, Transfer Stude...      NaN          NaN
#
#                                                   Cast Production companies  \
# 192  Choi Hyun Suk, Park Ji Hoon, Kim Jun Kyu, Yosh...     YG Entertainment
#
#      Rank
# 192  #193

# %%
# Replace missing values in Director
kdrama_df.loc[192, "Director"] = "No Director"
kdrama_df.loc[192, "Screenwriter"] = "No Screenwriter"

# %%
# Missing value in Production Companies
kdrama_df[kdrama_df["Production companies"].isnull()]
# Out:
#               Name                  Aired Date  Year of release  \
# 218      Angry Mom  Mar 18, 2015 - May 7, 2015             2015
# 240  Coffee Prince  Jul 2, 2007 - Aug 28, 2007             2007
#
#     Original Network             Aired On  Number of Episodes       Duration  \
# 218              MBC  Wednesday, Thursday                  16  1 hr. 10 min.
# 240              MBC      Monday, Tuesday                  17        60 min.
#
#               Content Rating  Rating  \
# 218  15+ - Teens 15 or older     8.3
# 240  15+ - Teens 15 or older     8.3
#
#                                               Synopsis  \
# 218  The protagonist, Jo Kang Ja was once legendary...
# 240  Choi Han Gyul is the grandson of chairwoman Ba...
#
#                             Genre  \
# 218      Comedy, Drama, Melodrama
# 240  Food, Comedy, Romance, Drama
#
#                                                   Tags       Director  \
# 218  Independent Female Lead, Mother-Daughter Relat...         Ashbun
# 240  Cross-Dressing, Hidden Identity, Boss-Employee...  Lee Yoon Jung
#
#                    Screenwriter  \
# 218                  Kim Ban Di
# 240  Jang Hyun Joo, Lee Jung Ah
#
#                                                   Cast Production companies  \
# 218  Kim Hee Sun, Kim Yoo Jung, Ji Hyun Woo, Kim Ji...                  NaN
# 240  Gong Yoo, Yoon Eun Hye, Lee Sun Kyun, Chae Jun...                  NaN
#
#      Rank
# 218  #219
# 240  #241

# %%
# Replace missing values in Production companies
kdrama_df.loc[218, "Production companies"] = "No Company"
kdrama_df.loc[240, "Production companies"] = "No Company"

# %%
# Check for missing values again
kdrama_df.isnull().sum()
# Out:
# Name                    0
# Aired Date              0
# Year of release         0
# Original Network        0
# Aired On                0
# Number of Episodes      0
# Duration                0
# Content Rating          0
# Rating                  0
# Synopsis                0
# Genre                   0
# Tags                    0
# Director                0
# Screenwriter            0
# Cast                    0
# Production companies    0
# Rank                    0
# dtype: int64

# %% [markdown]
# #3. Feature Engineering

# %% [markdown]
# ###Extracting Days of the Week

# %%
# String split Aired On column
kdrama_df["Aired On"] = kdrama_df["Aired On"].map(lambda days: days.strip().split(", "))

# %%
# Perform Multi-label Encoding on Aired On column
mlb = MultiLabelBinarizer()
days = mlb.fit_transform(kdrama_df["Aired On"])
days.shape
# Out:
# (250, 7)

# %%
# Merge new dataset with old
days_of_week_df = pd.DataFrame(days, columns = mlb.classes_)
days_of_week_df = pd.concat([kdrama_df, days_of_week_df], axis = 1)

# %%
# Convert rank to integer
days_of_week_df["Rank"] = days_of_week_df["Rank"].str[1:].astype(int)

# %%
# Split rank by range of values
conditions = [
    (days_of_week_df["Rank"] <= 50),
    ((days_of_week_df["Rank"] > 50) & (days_of_week_df["Rank"] <= 100)),
    ((days_of_week_df["Rank"] > 100) & (days_of_week_df["Rank"] <= 150)),
    ((days_of_week_df["Rank"] > 150) & (days_of_week_df["Rank"] <= 200)),
    (days_of_week_df["Rank"] > 200),
]
values = ["1 - 50", "51 - 100", "101 - 150", "151 - 200", "201 - 250"]

# Add new column for range of ranks
days_of_week_df["RankRange"] = np.select(conditions, values)

# %%
# Create dataframe for frequency of dramas aired on each day of the week
days_of_week_freq = pd.DataFrame(days_of_week_df.iloc[:, -8:-1].sum(axis = 0))

# Reset index and column names
days_of_week_freq = days_of_week_freq.reset_index()
days_of_week_freq.rename(columns = {"index": "Day of Week", 0: "Frequency"}, inplace = True)

# Reorder by days of the week
days_of_week_freq = days_of_week_freq.loc[[1, 5, 6, 4, 0, 2, 3]]

# Abbreviate days of the week
days_of_week_freq["Day of Week"] = days_of_week_freq["Day of Week"].str[:3]

days_of_week_freq
# Out:
#   Day of Week  Frequency
# 1         Mon         63
# 5         Tue         65
# 6         Wed         71
# 4         Thu         69
# 0         Fri         62
# 2         Sat         94
# 3         Sun         50

# %% [markdown]
# #4. Data Visualization

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
# Tree Map of which days of the week popular dramas are aired on
import squarify

sns.set_style(style = "whitegrid")
labels = days_of_week_freq["Day of Week"]
colors = [plt.cm.Spectral(i / float(len(labels))) for i in range(len(labels))]
treemap_labels = [x + " - " for x in labels] + days_of_week_freq["Frequency"].astype(str)
squarify.plot(sizes = days_of_week_freq["Frequency"], label = treemap_labels, alpha = 0.6, color = colors)
plt.title("Day of the Week Popular Dramas are Aired On", weight = "bold")
plt.axis('off')
plt.show()

# %%
# Line plot of number of top-250 dramas aired on each day of the week
sns.set_style(style = "darkgrid")
daysofweek_plot = sns.lineplot(data = days_of_week_freq, x = "Day of Week", y = "Frequency", marker = "o", linewidth = 0.8)
plt.xlabel("Day of the Week")
plt.ylabel("Number of Top-250 Dramas")
plt.title("Number of Top-250 Dramas Aired on each Day of the Week", pad = 15, color = "#333333", weight = "bold")
plt.show()

# %%
# Number of dramas aired on each day for each rank range
dayofweek_columns = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
rankrange_df = days_of_week_df.groupby(["RankRange"])[dayofweek_columns].sum()

# Reorder by days of the week
rankrange_df = rankrange_df.loc[["1 - 50", "51 - 100", "101 - 150", "151 - 200", "201 - 250"]]

# Abbreviate days of the week
rankrange_df.rename({"Monday": "Mon", "Tuesday": "Tues", "Wednesday": "Wed", "Thursday": "Thurs", "Friday": "Fri", "Saturday": "Sat", "Sunday": "Sun"}, axis = 1, inplace = True)

# Swap rows and columns
rankrange_df = rankrange_df.T
rankrange_df
# Out:
# RankRange  1 - 50  51 - 100  101 - 150  151 - 200  201 - 250
# Mon             8        14         12         15         14
# Tues            8        14         13         14         16
# Wed             9        11         15         22         14
# Thurs          11        11         13         20         14
# Fri            17        13         13         11          8
# Sat            26        21         20          8         19
# Sun            14        12          9          2         13

# %%
# Line plot of number of top-250 dramas aired on each day of the week for each rank range
rankrange_df.plot(marker = "o", markersize = 5, linewidth = 1, alpha = 0.7)

plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left', title = "Drama Ranking")
plt.xlabel("Day of the Week")
plt.ylabel("Number of Top-250 Dramas")
plt.title("Number of Top-250 Dramas Aired on each Day of the Week", pad = 15, color = "#333333", weight = "bold")
plt.show()

# %% [markdown]
# # 5. Recommendation System

# %%
# Convert cast to list
kdrama_df["Cast"] = kdrama_df["Cast"].map(lambda casts: casts.split(", "))

# %%
# Extract top 5 actors
kdrama_df["Top 5 Actors"] = kdrama_df["Cast"].apply(lambda x : list(x)[:5] if isinstance(x, list) else [])

# Join list of top 5 actors into string
kdrama_df["Top 5 Actors"] = kdrama_df["Top 5 Actors"].apply(lambda x : ", ".join(x))

# %%
# Convert features to strings
kdrama_df["Number of Episodes"] = kdrama_df["Number of Episodes"].astype(str)
kdrama_df["Genre"] = kdrama_df["Genre"].astype(str)
kdrama_df["Tags"] = kdrama_df["Tags"].astype(str)
kdrama_df["Top 5 Actors"] = kdrama_df["Top 5 Actors"].astype(str)

# %%
# Features used for recommender
extract_features = ["Number of Episodes", "Genre", "Tags", "Top 5 Actors"]

# Combine all features into one string
kdrama_df["Combined Features"] = kdrama_df[extract_features].apply(lambda x: ", ".join(x), axis = 1)
kdrama_df["Combined Features"]
# Out:
# 0      10, Life,  Drama,  Family , Autism, Uncle-Neph...
# 1      16, Thriller,  Romance,  Crime,  Melodrama , M...
# 2      12, Friendship,  Romance,  Life,  Medical , St...
# 3      12, Friendship,  Romance,  Life,  Medical , Wo...
# 4      16, Psychological,  Life,  Drama,  Family , Ag...
#                              ...
# 245    16, Historical, Romance, Medical, Fantasy, Tim...
# 246    20, Historical, Romance, Melodrama, Political,...
# 247    16, Law, Romance, Life, Drama, Alzheimer's Dis...
# 248    20, Horror, Comedy, Romance, Fantasy, Ghost-se...
# 249    14, Action, Thriller, Mystery, Crime, Investig...
# Name: Combined Features, Length: 250, dtype: object

# %%
# Calculate word weightage in combined features
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(analyzer = "word", stop_words = "english")
vec_matrix = vectorizer.fit_transform(kdrama_df["Combined Features"])

# %%
# Calculate similarity score between each pair of dramas
from sklearn.metrics.pairwise import cosine_similarity
similarity_matrix = cosine_similarity(vec_matrix)
similarity_matrix
# Out:
# array([[1.        , 0.03223875, 0.08014603, ..., 0.19964104, 0.08531444,
#         0.06585763],
#        [0.03223875, 1.        , 0.02408548, ..., 0.03505064, 0.11916618,
#         0.11037812],
#        [0.08014603, 0.02408548, 1.        , ..., 0.08297465, 0.07601846,
#         0.04235218],
#        ...,
#        [0.19964104, 0.03505064, 0.08297465, ..., 1.        , 0.06834958,
#         0.04959811],
#        [0.08531444, 0.11916618, 0.07601846, ..., 0.06834958, 1.        ,
#         0.20021601],
#        [0.06585763, 0.11037812, 0.04235218, ..., 0.04959811, 0.20021601,
#         1.        ]])

# %%
def rec_top_5(drama, print_rec = True):
  '''
  Recommend 5 other dramas based on user's input drama

  Args:
  -----
  drama: Name of user's input drama

  Returns:
  --------
  Print top 5 recommended dramas based on similarity score
  '''

  # Index of user's input drama
  index = kdrama_df.loc[(kdrama_df["Name"] == drama)].index[0]

  # Sort similarity scores with other dramas
  similarity_ranking = np.argsort(similarity_matrix[index])

  # Extract index of top 5 similar dramas
  top_5_index = similarity_ranking[-6:-1][::-1]

  # Store top 5 recommended dramas in list
  top_5_dramas = []

  for rank, idx in enumerate(top_5_index):
    recommend = kdrama_df.iloc[idx]["Name"]
    top_5_dramas.append(recommend)

    # Print top 5 recommended dramas
    if print_rec:
      print("#{rank}: ".format(rank = rank + 1) + recommend)

  return top_5_dramas

# %%
# Keep prompting user until valid input drama
while True:
  try:
    drama = input("Enter the name of your favorite drama: ")
    rec_top_5(drama)
    break

  # Drama name not in database
  except IndexError:
    print("Sorry, drama not found. Please try again!")
# Out:
# Enter the name of your favorite drama: Descendants of the Sun
# #1: Just Between Lovers
# #2: Vincenzo
# #3: Player
# #4: Arthdal Chronicles Part 1
# #5: Chicago Typewriter

# %%
# Extract list of top 250 dramas
top_250_dramas = kdrama_df["Name"].tolist()

# Make predictions for all 250 dramas
pred_popularity = {}
for drama in top_250_dramas:
  top_5_dramas = rec_top_5(drama, print_rec = False)
  for recommend in top_5_dramas:
    if recommend in pred_popularity:
      pred_popularity[recommend] += 1
    else:
      pred_popularity[recommend] = 1

# Sort prediction popularity in desc order
pred_popularity = sorted(pred_popularity.items(), key = lambda x: x[1], reverse = True)

# %%
# Create dataframe of prediction popularity
top5_occurrence_df = pd.DataFrame(pred_popularity, columns = ["Drama", "Number of Recommendations"])

# %%
# Bar chart of top 10 dramas with most recommendations
barchart_df = top5_occurrence_df.head(10)
sns.set(style="darkgrid")
top5_occurrence_plot = sns.barplot(data = barchart_df, x = "Number of Recommendations", y = "Drama")
top5_occurrence_plot.set(ylabel = None)
plt.xlabel("Number of Top 5 Recommendations")
plt.title("Dramas with Most Top 5 Recommendations", pad = 15, color = "#333333", weight = "bold")
plt.show()

# %%
# Create instance of directed graph
rec_graph = nx.DiGraph()

# Add pairs of (given drama, recommended drama) as edge
for drama in top_250_dramas[:100]:
  top_5_dramas = rec_top_5(drama, print_rec = False)
  for rec in top_5_dramas:
    if rec in top_250_dramas[:100]:
      rec_graph.add_edge(drama, rec)

# Create interactive graph
net = Network(directed = True, notebook = True, cdn_resources = "remote")
net.from_nx(rec_graph)
net.show("network.html")
IPython.display.HTML("network.html")
# Out:
# network.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
#
#
#
#
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 600px;
#                  backgr
